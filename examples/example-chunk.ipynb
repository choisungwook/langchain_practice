# %% [markdown]
# # PDF 문서를 읽어 chunk

# %%
from langchain.document_loaders import PyPDFLoader
loader = PyPDFLoader("./PDFS/sample-statement-of-work.pdf")
doc = loader.load()

# %%
len(doc)
# Out:
# 9

# %%
for i, _ in enumerate(doc):
  print(f"chunk # {i}, size: {doc[i]}")
# Out:
# chunk # 0, size: page_content='STATEMENT OF WORK  \n{example SaaS software project}  \n \nCONTRACT ID: {unique reference}  \n \nDATE OF CONTRACT: {date}  \n \nFOR: ACME Company  \nPREPARED BY: Globex  \n \nProject: Ticket Linking Completion  \n \nVersion History  \nVersion  Change  Modified By  Date  \n0.1 Initial draft  Project Manager  09/23  \n0.2 Dev review  Developer  09/30  \n0.3 Correction of exchange rates  Project Manager  10/02  \n0.4 PMO review  PMO  10/03  \n \nDistribution List  \nPerson  Role/Title  Approver (Y/N)  \nA Smith  ACME Sponsor  Y \nP Dole  Supplier Sponsor  Y \nD Fred  PMO Director  Y \nTbc ACME Project Manager  N \nT Leap  Supplier Project Manager  N \n \n  \n' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 0}
# chunk # 1, size: page_content=' \nPage 2 of 9 \n SAMPLE STATEMENT OF WORK  \nContents  \nSTATEMENT OF WORK  ................................ ................................ ................................ ..............  1 \nVersion History  ................................ ................................ ................................ ...........................  1 \nDistribution List  ................................ ................................ ................................ .........................  1 \nBusiness Challenges  ................................ ................................ ................................ .......................  3 \nSolution Overview  ................................ ................................ ................................ ..........................  3 \nProject Deliverables  ................................ ................................ ................................ ........................  4 \nProject Management  ................................ ................................ ................................ ...................  4 \nDevelopment  ................................ ................................ ................................ ................................  4 \nQuality Assurance ................................ ................................ ................................ .......................  4 \nAdministration Support  ................................ ................................ ................................ .............  4 \nCustom Report  ................................ ................................ ................................ ............................  5 \nRisks  ................................ ................................ ................................ ................................ ................  6 \nAssumptions  ................................ ................................ ................................ ................................ .... 6 \nOverall project assumptions ................................ ................................ ................................ ....... 6 \nTechnology Assumptions  ................................ ................................ ................................ ............  7 \nExclusions  ................................ ................................ ................................ ................................ .... 7 \nRoles and responsibiliti es ................................ ................................ ................................ ..............  8 \nOnsite requirements  ................................ ................................ ................................ .......................  8 \nRates  ................................ ................................ ................................ ................................ ................  8 \nFees Summary  ................................ ................................ ................................ ............................  8 \nPayment Terms  ................................ ................................ ................................ ...............................  9 \nExpenses  ................................ ................................ ................................ ................................ ..........  9 \nSignatures  ................................ ................................ ................................ ................................ ....... 9 \n \n  ' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 2, size: page_content=' \nPage 3 of 9 \n SAMPLE STATEMENT OF WORK  \nBusiness Challenges  \n \nACME is an existing SaaS customer. In order to link tickets together to a root problem and \nbe able to respond to those linked tickets in a single step, as well as providing ITIL \nmethodology directives, Globex has provided a prototype configuration and cust omisation in \norder to achieve the desired functionality.  \nA further project was undertaken to include additional enhancements linked to this work \nand these have been provided in a test environment to prove the additional functionality.  \nACME have approved th e functionality of the prototype and require migration of the ticket \nmanagement functionality into the production environment.   \nIn addition, there is a requirement to provide management information in the form of a \ncustom report for the functionality rela ting to ticket  linking.  \nSolution Overview  \nGlobex  has provided the description of the services to be performed in the Deliverables  \nsection below.  Further requirements and or customizations defined or requested by \nCustomer after baseline acceptance of this Statement of Work could change the scope of this \nproject and will be managed according to the Change Management process defined i n the \nChange Management Appendix . \nThe solution will eventually comprise:  \nCustomisation and Configuration functionality from Prototype to the production \nenvironment  \nCustom Reports for the new configuration / c ustomisation  \nRegional Interface and Language Requirement s  \n• acme    : en_GB  \n• acme da : da_DK  \n• acme de : de_DE  \n• acme es  : es_ES  \n• acme fr  : fr_FR  \n• acme it  : it_IT  \n• acme us : en_US  \nFunctional Scope:  \n• Migration of customisations  \n• Custom report  \n \nThe proposed process for the Globex  delivery is:  ' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 3, size: page_content=' \nPage 4 of 9 \n SAMPLE STATEMENT OF WORK  \n• Project Management  \n• Application Development  \n• Quality Assurance Testing  \n• Support for Users  \nProject Deliverables  \nThe following section defines and explains the key deliverables for this Consulting services  \nengagement .   \nProject Management  \nGlobex ’s Project Manager  (PM) will be responsible for managing the level of effort associated \nwith this Sta tement of Work.  The PM will develop the Project Plan  which describes the \ntasks, activities, milestones  and timelines associated with this engagement.  The Project \nManager  will maintain a risks /issues log and record project  progress in  the form of weekly \nstatus reports .  A Delivery Manager will have responsibility for delivery assurance  and will \nserve as an escalation point of contact for the project team .  \nThe Customer will designate one person to serve  as Project Manager .  The Customer’s \nproject manager  will have authority to approve project -related services and may designate \nother individuals to act as project manager s, subject -matter experts, and /or advisors  during \nthe engagement .  The Customer  will be responsible for the quality and timeliness of work \nperformed by Customer in support of this project; any schedule  delays that result is subject \nto the hourly rates outlined in the Rates section of this document.  \nDeliverables:  \nProject Plan:   documents project activiti es, ownership of those activities , milestones , \nschedule , and dependenc ies. \nDevelopment  \nGlobex developer will migrate the required customisations from the prototype environment \nto the production environment according to the project plan.  \nQuality Assurance  \nGlobex will test the system as identified in the Project Plan and will certify the system is \nready for Acceptance Testing.  \nACME will be responsible for acceptance testing against its business requirements. This \nincludes test planning and management, test case  development, and execution of acceptance \ntests at the individual test case  level. Globex services will be limited to assisting the \nCustomer with test case  execution, investigating the root cause of failed test case s and \nassisting with resolution (if applicable).  \nAdministration Support  \nGlobex will provide support to ACME to the point of a successful deployment of the \nfunctional changes as agree d in the Project Plan.  ' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 4, size: page_content=' \nPage 5 of 9 \n SAMPLE STATEMENT OF WORK  \nGlobex consultant will provide support to one designated ACME contact by way of an online \nworkshop as to the functionality, management and maintenance of the configuration \nchanges.  \nCustom Report  \nGlobex consultant will provide ACME wi th one standard Globex report as described in the \nProject plan and is likely to include the following filters and columns.  \nFixed Filter: Ticket Type = Problem  \nRuntime Filters:  Problem Assigned  \n   Problem Product  \n   Problem Priority  \n   Problem Status  \n   Problem Created date Range.  \nColumns (1st level)  Problem Number  \n   Problem Subject  \n   Problem Assigned  \n   Problem Product  \n   Problem Priority  \n   Problem Status  \n   Count (Related Tickets)  \nColumns (2nd level)  Ticket Reference  \n   Ticket Subject  \n   Ticket Assigne d \n   Ticket Product  \n   Ticket Priority  \n   Ticket Status  \n     \nDrill -down features will be provided by the use of  Rollups. Initially the report will be in \nexpanded mode – showing all (selected) problems and tickets. The user may click above the \nfirst collapse button to collapse all and the result is one problem per line with the count of \ntickets.  ' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 5, size: page_content=' \nPage 6 of 9 \n SAMPLE STATEMENT OF WORK  \nRisks  \nRisk Assessment  is a process to identify, analyse , plan, track and control risks  related to the \nimplementation of or  integration with the Globex  Software.  There are potential risks  \nassoc iated with the project that need to be addressed via a mitigation strategy.  Below are \nthe identified risks  associated with this project:  \nRisk  Mitigation  \nAdoption of the software  Globex will assist with promotion of the tool and training.  \nDeployment of the \nchanges  Globex  will monitor the deployment of the integrated \nsolution and adjust the project plan as necessary.  \nResource availability  Secure approval from project sponsors to supp ort project \nthrough completion.  \n  \n \nAssumptions  \nAssumptions are factors used for planning purposes that are considered true, real, or \ncertain.  Assumptions help define scope and determine level of effort and timeframes.  \n \nOverall project assumptions  \n1. This project assumes  7 Globex instances  will be involved in this project  in the \nfollowing languages: English  \n2. The Services included in this Statement of Work will be performed:  Offsite  \n3. Engagement Locations are: Globex offices . \n4. The Customer  will be charged for all travel and related expenses according to \nGlobex ’s travel policies unless otherwise noted.  – Travel and related expenses will \nnot be recharged as per agreement with ACME  \n5. Globex will provide a RNT Certified Project Manager  and may utilize Globex \ncertified third party resources to complete some or all of the work on this \nengagement.  \n6. Customer will designate one person to act as a project manager .  The Customer ’s \nproject manager  will have sole authority to approve and sign -off all project services \nas well as manage the project from the Customer  perspective.  For the purpose of \ndaily operations, the Customer ’s project manager  may designate other individuals to \nact as project manager s, subject -matter experts, and advisors.  \n7. Globex  will provide the Customer  with weekly status reports  and a project charter  \ndocumenting the project materials and schedule . \n8. Customer  will be responsible for the scheduling, availability, quality, and timeliness \nof work its resources perform.  Any schedule  delays that result are subject to the \nbillable rate illustrated in this document.  \n9. Client will be responsible for any acceptance testing against its business \nrequirements, subsequent rollout phases of this project not speci fically identified in \nthis Statement of Work.  \n10. All services must be used within 12 months of purchase to avoid expiration.  ' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 6, size: page_content=' \nPage 7 of 9 \n SAMPLE STATEMENT OF WORK  \nTechnology Assumptions  \n1. The Customer’s IT organization is responsible for workstation compliance to Globex  \nminimum requirements and any  pre-installation activities (if applicable).  \n2. Customer is responsible for the purchase and installation of any third -party \napplication/s. Globex  is not responsible for obtaining data from 3rd party applications \nfor integration purposes.   \n3. Customer is respo nsible for ensuring all data integrated with the Globex  Service is in \nthe proper format before it is integrated if  integration is included in this Statement \nof Work.  \n4. Customer will provide Globex  staff access to existing systems as they apply during \nthe imp lementation, testing, and rollout of the Globex  Applications.  \n5. Customer will be responsible for any acceptance testing against its business \nrequirements, any pilot implementations, rollout, and any subsequent rollout phases \nof this project not specifically identified in this Statement of Work.  \n6. Globex  will not modify any non -Globex  application pages (i.e., pages that are a part \nof the core Customer website.)  \nExclusions  \nIn addition to identifying the specific components that are included in the project, it is \nequally important to specify  those components that are NOT included in the Statement of \nWork in order to manage expectations and scope.  The following list of items is specifically \nexcluded from this statement of work : \n1. Analysis, documentation, or configuration of Security outside of the Globex  \napplication.  \n2. Analysis, documentation, development, or deployment of Data Exports to 3rd party \nexternal systems.  \n3. Offer Advisor Middleware, Computer Telephony Integration (CTI) and Voice Self -\nService implementation.  \n4. Pass Thru Authentication (PTA), Application Programming Interface (API), and \nPremier Customization Access (PCA).  \n5. Formal training other than described in this Statement of Work.  \n6. Globex  is not responsible for advanced Database, Operating System and Network \nconfiguration and/or troubleshooting are outside the scope of this Statement of Work.  \nThis includes, but is not limited to:  \n• Database Replication,  Optimization or Partit ions \n• Router/Switch troubleshooting  \n• DNS issues  and SSL configuration  \n• Internet Connectivity  \n• TCP/IP configuration  \n• Network Appliance setup/troubleshooting  \n• Web Server set -up and troubleshooting  \n• Remote Access Customer/server configuration  \n• Windows and/or any othe r OS Installation  ' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 7, size: page_content=' \nPage 8 of 9 \n SAMPLE STATEMENT OF WORK  \nRoles and responsibilities  \nDetailed Project Team  roles and responsibilities are defined in the Project Charter .  \nOnsite requirements  \nThe section identifies services & property that the Customer  is to provide the Globex  \nConsulting services  team in support of the project while onsite.  \n1. Telephone service for local and long -distance calls that pertain to supporting the \nproject.  \n2. Internet Access (network or dial -out) \n3. Access to Customer ’s computer hardware and software systems that apply to this \nproject.  \n4. Work facilities to perform that required work that is stated within this project.  \nRates  \nServices provided under this Statement of Work shall be based on Globex  standard \nconsulting  rates, which are listed below:  \nRole  Euros  \nDeveloper  €1,200/day  \nConsultant  €1,200/day  \nTest Manager  €1,200/day  \nEducation Trainer  €1,200/day  \nProject Manager  €1,200/day  \nBusiness Development Manager  €1,200/day  \n \nGlobex  may utilize a Globex  certified third party vendor to complete all or some of the work \nspecified in this statement of work.  Documented below are the estimated Consulting \nservices  fees. \nFees Summary  \nThis estimate does not include travel and “out of pocket” expenses Globex may incur.  \nCONSULTING SERVICE  DAYS  FEE  \nDeliverable 1  Project Management  8 € 9,600  \nDeliverable 2  Development  6 € 7,200  \nDeliverable 3  Quality Assurance Testing  4 € 4,800  \nDeliverable 4  Administration Support  4 € 4,800  \nDeliverable 5  Custom Report  6 € 7,200  \nTOTAL:  28 € 33,600  ' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 8, size: page_content=' \nPage 9 of 9 \n SAMPLE STATEMENT OF WORK  \nPayment Terms  \nFixed Fee  \nGlobex will invoice the Customer following signature of this Statement of Work and \npayments shall be due net thirty (30) days from invoice date.  Without limiting its rights or \nremedies, Globex  shall have the right to halt or terminate entirely any services until \npayment is received on past -due invoices.  \nCustomer shall pay to Globex a fee of thirty -three  thousand six hundred Euros (€ 33,600 ) \n(“Fee”) for Services described in this Statement of Work, plus  actual expenses incurred for \nthe duration of the project.  \nExpenses  \nEstimate s do not include travel and related expenses Globex  may incur in support of this \nengagement . Globex  will send an invoice on a monthly basis for expenses incurred during \nthe previous month.  Payments for such invoices are due net thirty (30) days from date of \ninvoice.  \nTerms & Conditions  \nGlobex  Standard Terms and Conditions govern this Statement of Work a nd may be viewed \nat http://www.globex.com/saas/agreements/master.html .  \nSignatures  \n \nGlobex , Inc.  \nConsulting services  ACME  \n \n \n  \n \n \nName:    Name:   \nTitle :  VP consulting services  Title:  Procurement Director  \nDate :   Date:   \n ' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
  chunk_size = 100,
  chunk_overlap  = 0,
  length_function = len,
)
chunks = text_splitter.split_documents(doc)

# %%
len(chunks)
# Out:
# 229

# %%
for i, _ in enumerate(chunks):
  print(f"chunk # {i}, size: {chunks[i]}")
# Out:
# chunk # 0, size: page_content='STATEMENT OF WORK  \n{example SaaS software project}  \n \nCONTRACT ID: {unique reference}' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 0}
# chunk # 1, size: page_content='DATE OF CONTRACT: {date}  \n \nFOR: ACME Company  \nPREPARED BY: Globex' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 0}
# chunk # 2, size: page_content='Project: Ticket Linking Completion  \n \nVersion History  \nVersion  Change  Modified By  Date' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 0}
# chunk # 3, size: page_content='0.1 Initial draft  Project Manager  09/23  \n0.2 Dev review  Developer  09/30' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 0}
# chunk # 4, size: page_content='0.3 Correction of exchange rates  Project Manager  10/02  \n0.4 PMO review  PMO  10/03' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 0}
# chunk # 5, size: page_content='Distribution List  \nPerson  Role/Title  Approver (Y/N)  \nA Smith  ACME Sponsor  Y' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 0}
# chunk # 6, size: page_content='P Dole  Supplier Sponsor  Y \nD Fred  PMO Director  Y \nTbc ACME Project Manager  N' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 0}
# chunk # 7, size: page_content='T Leap  Supplier Project Manager  N' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 0}
# chunk # 8, size: page_content='Page 2 of 9 \n SAMPLE STATEMENT OF WORK  \nContents' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 9, size: page_content='STATEMENT OF WORK  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 10, size: page_content='................................ ..............  1' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 11, size: page_content='Version History  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 12, size: page_content='................................ ...........................  1' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 13, size: page_content='Distribution List  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 14, size: page_content='................................ .........................  1' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 15, size: page_content='Business Challenges  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 16, size: page_content='................................ .......................  3' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 17, size: page_content='Solution Overview  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 18, size: page_content='................................ ..........................  3' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 19, size: page_content='Project Deliverables  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 20, size: page_content='................................ ........................  4' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 21, size: page_content='Project Management  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 22, size: page_content='................................ ...................  4' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 23, size: page_content='Development  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 24, size: page_content='................................ ................................  4' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 25, size: page_content='Quality Assurance ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 26, size: page_content='................................ .......................  4' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 27, size: page_content='Administration Support  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 28, size: page_content='................................ .............  4' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 29, size: page_content='Custom Report  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 30, size: page_content='................................ ............................  5' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 31, size: page_content='Risks  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 32, size: page_content='................................ ................................ ................  6' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 33, size: page_content='Assumptions  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 34, size: page_content='................................ ................................ .... 6' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 35, size: page_content='Overall project assumptions ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 36, size: page_content='................................ ....... 6' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 37, size: page_content='Technology Assumptions  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 38, size: page_content='................................ ............  7' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 39, size: page_content='Exclusions  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 40, size: page_content='................................ ................................ .... 7' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 41, size: page_content='Roles and responsibiliti es ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 42, size: page_content='................................ ..............  8' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 43, size: page_content='Onsite requirements  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 44, size: page_content='................................ .......................  8' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 45, size: page_content='Rates  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 46, size: page_content='................................ ................................ ................  8' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 47, size: page_content='Fees Summary  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 48, size: page_content='................................ ............................  8' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 49, size: page_content='Payment Terms  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 50, size: page_content='................................ ...............................  9' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 51, size: page_content='Expenses  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 52, size: page_content='................................ ................................ ..........  9' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 53, size: page_content='Signatures  ................................ ................................' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 54, size: page_content='................................ ................................ ....... 9' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 1}
# chunk # 55, size: page_content='Page 3 of 9 \n SAMPLE STATEMENT OF WORK  \nBusiness Challenges' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 56, size: page_content='ACME is an existing SaaS customer. In order to link tickets together to a root problem and' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 57, size: page_content='be able to respond to those linked tickets in a single step, as well as providing ITIL' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 58, size: page_content='methodology directives, Globex has provided a prototype configuration and cust omisation in' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 59, size: page_content='order to achieve the desired functionality.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 60, size: page_content='A further project was undertaken to include additional enhancements linked to this work' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 61, size: page_content='and these have been provided in a test environment to prove the additional functionality.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 62, size: page_content='ACME have approved th e functionality of the prototype and require migration of the ticket' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 63, size: page_content='management functionality into the production environment.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 64, size: page_content='In addition, there is a requirement to provide management information in the form of a' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 65, size: page_content='custom report for the functionality rela ting to ticket  linking.  \nSolution Overview' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 66, size: page_content='Globex  has provided the description of the services to be performed in the Deliverables' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 67, size: page_content='section below.  Further requirements and or customizations defined or requested by' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 68, size: page_content='Customer after baseline acceptance of this Statement of Work could change the scope of this' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 69, size: page_content='project and will be managed according to the Change Management process defined i n the' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 70, size: page_content='Change Management Appendix . \nThe solution will eventually comprise:' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 71, size: page_content='Customisation and Configuration functionality from Prototype to the production \nenvironment' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 72, size: page_content='Custom Reports for the new configuration / c ustomisation' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 73, size: page_content='Regional Interface and Language Requirement s  \n• acme    : en_GB  \n• acme da : da_DK' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 74, size: page_content='• acme de : de_DE  \n• acme es  : es_ES  \n• acme fr  : fr_FR  \n• acme it  : it_IT' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 75, size: page_content='• acme us : en_US  \nFunctional Scope:  \n• Migration of customisations  \n• Custom report' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 76, size: page_content='The proposed process for the Globex  delivery is:' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 2}
# chunk # 77, size: page_content='Page 4 of 9 \n SAMPLE STATEMENT OF WORK  \n• Project Management  \n• Application Development' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 78, size: page_content='• Quality Assurance Testing  \n• Support for Users  \nProject Deliverables' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 79, size: page_content='The following section defines and explains the key deliverables for this Consulting services' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 80, size: page_content='engagement .   \nProject Management' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 81, size: page_content='Globex ’s Project Manager  (PM) will be responsible for managing the level of effort associated' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 82, size: page_content='with this Sta tement of Work.  The PM will develop the Project Plan  which describes the' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 83, size: page_content='tasks, activities, milestones  and timelines associated with this engagement.  The Project' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 84, size: page_content='Manager  will maintain a risks /issues log and record project  progress in  the form of weekly' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 85, size: page_content='status reports .  A Delivery Manager will have responsibility for delivery assurance  and will' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 86, size: page_content='serve as an escalation point of contact for the project team .' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 87, size: page_content='The Customer will designate one person to serve  as Project Manager .  The Customer’s' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 88, size: page_content='project manager  will have authority to approve project -related services and may designate' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 89, size: page_content='other individuals to act as project manager s, subject -matter experts, and /or advisors  during' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 90, size: page_content='the engagement .  The Customer  will be responsible for the quality and timeliness of work' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 91, size: page_content='performed by Customer in support of this project; any schedule  delays that result is subject' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 92, size: page_content='to the hourly rates outlined in the Rates section of this document.  \nDeliverables:' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 93, size: page_content='Project Plan:   documents project activiti es, ownership of those activities , milestones ,' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 94, size: page_content='schedule , and dependenc ies. \nDevelopment' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 95, size: page_content='Globex developer will migrate the required customisations from the prototype environment' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 96, size: page_content='to the production environment according to the project plan.  \nQuality Assurance' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 97, size: page_content='Globex will test the system as identified in the Project Plan and will certify the system is' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 98, size: page_content='ready for Acceptance Testing.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 99, size: page_content='ACME will be responsible for acceptance testing against its business requirements. This' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 100, size: page_content='includes test planning and management, test case  development, and execution of acceptance' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 101, size: page_content='tests at the individual test case  level. Globex services will be limited to assisting the' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 102, size: page_content='Customer with test case  execution, investigating the root cause of failed test case s and' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 103, size: page_content='assisting with resolution (if applicable).  \nAdministration Support' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 104, size: page_content='Globex will provide support to ACME to the point of a successful deployment of the' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 105, size: page_content='functional changes as agree d in the Project Plan.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 3}
# chunk # 106, size: page_content='Page 5 of 9 \n SAMPLE STATEMENT OF WORK' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 107, size: page_content='Globex consultant will provide support to one designated ACME contact by way of an online' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 108, size: page_content='workshop as to the functionality, management and maintenance of the configuration \nchanges.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 109, size: page_content='Custom Report' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 110, size: page_content='Globex consultant will provide ACME wi th one standard Globex report as described in the' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 111, size: page_content='Project plan and is likely to include the following filters and columns.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 112, size: page_content='Fixed Filter: Ticket Type = Problem  \nRuntime Filters:  Problem Assigned  \n   Problem Product' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 113, size: page_content='Problem Priority  \n   Problem Status  \n   Problem Created date Range.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 114, size: page_content='Columns (1st level)  Problem Number  \n   Problem Subject  \n   Problem Assigned' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 115, size: page_content='Problem Product  \n   Problem Priority  \n   Problem Status  \n   Count (Related Tickets)' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 116, size: page_content='Columns (2nd level)  Ticket Reference  \n   Ticket Subject  \n   Ticket Assigne d' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 117, size: page_content='Ticket Product  \n   Ticket Priority  \n   Ticket Status' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 118, size: page_content='Drill -down features will be provided by the use of  Rollups. Initially the report will be in' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 119, size: page_content='expanded mode – showing all (selected) problems and tickets. The user may click above the' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 120, size: page_content='first collapse button to collapse all and the result is one problem per line with the count of' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 121, size: page_content='tickets.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 4}
# chunk # 122, size: page_content='Page 6 of 9 \n SAMPLE STATEMENT OF WORK  \nRisks' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 123, size: page_content='Risk Assessment  is a process to identify, analyse , plan, track and control risks  related to the' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 124, size: page_content='implementation of or  integration with the Globex  Software.  There are potential risks' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 125, size: page_content='assoc iated with the project that need to be addressed via a mitigation strategy.  Below are' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 126, size: page_content='the identified risks  associated with this project:  \nRisk  Mitigation' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 127, size: page_content='Adoption of the software  Globex will assist with promotion of the tool and training.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 128, size: page_content='Deployment of the \nchanges  Globex  will monitor the deployment of the integrated' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 129, size: page_content='solution and adjust the project plan as necessary.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 130, size: page_content='Resource availability  Secure approval from project sponsors to supp ort project' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 131, size: page_content='through completion.  \n  \n \nAssumptions' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 132, size: page_content='Assumptions are factors used for planning purposes that are considered true, real, or' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 133, size: page_content='certain.  Assumptions help define scope and determine level of effort and timeframes.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 134, size: page_content='Overall project assumptions' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 135, size: page_content='1. This project assumes  7 Globex instances  will be involved in this project  in the' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 136, size: page_content='following languages: English' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 137, size: page_content='2. The Services included in this Statement of Work will be performed:  Offsite' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 138, size: page_content='3. Engagement Locations are: Globex offices .' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 139, size: page_content='4. The Customer  will be charged for all travel and related expenses according to' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 140, size: page_content='Globex ’s travel policies unless otherwise noted.  – Travel and related expenses will' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 141, size: page_content='not be recharged as per agreement with ACME' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 142, size: page_content='5. Globex will provide a RNT Certified Project Manager  and may utilize Globex' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 143, size: page_content='certified third party resources to complete some or all of the work on this \nengagement.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 144, size: page_content='6. Customer will designate one person to act as a project manager .  The Customer ’s' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 145, size: page_content='project manager  will have sole authority to approve and sign -off all project services' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 146, size: page_content='as well as manage the project from the Customer  perspective.  For the purpose of' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 147, size: page_content='daily operations, the Customer ’s project manager  may designate other individuals to' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 148, size: page_content='act as project manager s, subject -matter experts, and advisors.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 149, size: page_content='7. Globex  will provide the Customer  with weekly status reports  and a project charter' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 150, size: page_content='documenting the project materials and schedule .' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 151, size: page_content='8. Customer  will be responsible for the scheduling, availability, quality, and timeliness' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 152, size: page_content='of work its resources perform.  Any schedule  delays that result are subject to the' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 153, size: page_content='billable rate illustrated in this document.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 154, size: page_content='9. Client will be responsible for any acceptance testing against its business' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 155, size: page_content='requirements, subsequent rollout phases of this project not speci fically identified in' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 156, size: page_content='this Statement of Work.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 157, size: page_content='10. All services must be used within 12 months of purchase to avoid expiration.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 5}
# chunk # 158, size: page_content='Page 7 of 9 \n SAMPLE STATEMENT OF WORK  \nTechnology Assumptions' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 159, size: page_content='1. The Customer’s IT organization is responsible for workstation compliance to Globex' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 160, size: page_content='minimum requirements and any  pre-installation activities (if applicable).' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 161, size: page_content='2. Customer is responsible for the purchase and installation of any third -party' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 162, size: page_content='application/s. Globex  is not responsible for obtaining data from 3rd party applications' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 163, size: page_content='for integration purposes.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 164, size: page_content='3. Customer is respo nsible for ensuring all data integrated with the Globex  Service is in' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 165, size: page_content='the proper format before it is integrated if  integration is included in this Statement \nof Work.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 166, size: page_content='4. Customer will provide Globex  staff access to existing systems as they apply during' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 167, size: page_content='the imp lementation, testing, and rollout of the Globex  Applications.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 168, size: page_content='5. Customer will be responsible for any acceptance testing against its business' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 169, size: page_content='requirements, any pilot implementations, rollout, and any subsequent rollout phases' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 170, size: page_content='of this project not specifically identified in this Statement of Work.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 171, size: page_content='6. Globex  will not modify any non -Globex  application pages (i.e., pages that are a part' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 172, size: page_content='of the core Customer website.)  \nExclusions' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 173, size: page_content='In addition to identifying the specific components that are included in the project, it is' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 174, size: page_content='equally important to specify  those components that are NOT included in the Statement of' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 175, size: page_content='Work in order to manage expectations and scope.  The following list of items is specifically' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 176, size: page_content='excluded from this statement of work :' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 177, size: page_content='1. Analysis, documentation, or configuration of Security outside of the Globex  \napplication.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 178, size: page_content='2. Analysis, documentation, development, or deployment of Data Exports to 3rd party' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 179, size: page_content='external systems.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 180, size: page_content='3. Offer Advisor Middleware, Computer Telephony Integration (CTI) and Voice Self -' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 181, size: page_content='Service implementation.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 182, size: page_content='4. Pass Thru Authentication (PTA), Application Programming Interface (API), and' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 183, size: page_content='Premier Customization Access (PCA).' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 184, size: page_content='5. Formal training other than described in this Statement of Work.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 185, size: page_content='6. Globex  is not responsible for advanced Database, Operating System and Network' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 186, size: page_content='configuration and/or troubleshooting are outside the scope of this Statement of Work.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 187, size: page_content='This includes, but is not limited to:  \n• Database Replication,  Optimization or Partit ions' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 188, size: page_content='• Router/Switch troubleshooting  \n• DNS issues  and SSL configuration  \n• Internet Connectivity' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 189, size: page_content='• TCP/IP configuration  \n• Network Appliance setup/troubleshooting' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 190, size: page_content='• Web Server set -up and troubleshooting  \n• Remote Access Customer/server configuration' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 191, size: page_content='• Windows and/or any othe r OS Installation' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 6}
# chunk # 192, size: page_content='Page 8 of 9 \n SAMPLE STATEMENT OF WORK  \nRoles and responsibilities' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 193, size: page_content='Detailed Project Team  roles and responsibilities are defined in the Project Charter .' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 194, size: page_content='Onsite requirements' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 195, size: page_content='The section identifies services & property that the Customer  is to provide the Globex' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 196, size: page_content='Consulting services  team in support of the project while onsite.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 197, size: page_content='1. Telephone service for local and long -distance calls that pertain to supporting the \nproject.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 198, size: page_content='2. Internet Access (network or dial -out)' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 199, size: page_content='3. Access to Customer ’s computer hardware and software systems that apply to this \nproject.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 200, size: page_content='4. Work facilities to perform that required work that is stated within this project.  \nRates' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 201, size: page_content='Services provided under this Statement of Work shall be based on Globex  standard' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 202, size: page_content='consulting  rates, which are listed below:  \nRole  Euros  \nDeveloper  €1,200/day' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 203, size: page_content='Consultant  €1,200/day  \nTest Manager  €1,200/day  \nEducation Trainer  €1,200/day' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 204, size: page_content='Project Manager  €1,200/day  \nBusiness Development Manager  €1,200/day' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 205, size: page_content='Globex  may utilize a Globex  certified third party vendor to complete all or some of the work' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 206, size: page_content='specified in this statement of work.  Documented below are the estimated Consulting' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 207, size: page_content='services  fees. \nFees Summary' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 208, size: page_content='This estimate does not include travel and “out of pocket” expenses Globex may incur.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 209, size: page_content='CONSULTING SERVICE  DAYS  FEE  \nDeliverable 1  Project Management  8 € 9,600' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 210, size: page_content='Deliverable 2  Development  6 € 7,200  \nDeliverable 3  Quality Assurance Testing  4 € 4,800' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 211, size: page_content='Deliverable 4  Administration Support  4 € 4,800  \nDeliverable 5  Custom Report  6 € 7,200' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 212, size: page_content='TOTAL:  28 € 33,600' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 7}
# chunk # 213, size: page_content='Page 9 of 9 \n SAMPLE STATEMENT OF WORK  \nPayment Terms  \nFixed Fee' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
# chunk # 214, size: page_content='Globex will invoice the Customer following signature of this Statement of Work and' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
# chunk # 215, size: page_content='payments shall be due net thirty (30) days from invoice date.  Without limiting its rights or' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
# chunk # 216, size: page_content='remedies, Globex  shall have the right to halt or terminate entirely any services until' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
# chunk # 217, size: page_content='payment is received on past -due invoices.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
# chunk # 218, size: page_content='Customer shall pay to Globex a fee of thirty -three  thousand six hundred Euros (€ 33,600 )' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
# chunk # 219, size: page_content='(“Fee”) for Services described in this Statement of Work, plus  actual expenses incurred for' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
# chunk # 220, size: page_content='the duration of the project.  \nExpenses' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
# chunk # 221, size: page_content='Estimate s do not include travel and related expenses Globex  may incur in support of this' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
# chunk # 222, size: page_content='engagement . Globex  will send an invoice on a monthly basis for expenses incurred during' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
# chunk # 223, size: page_content='the previous month.  Payments for such invoices are due net thirty (30) days from date of' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
# chunk # 224, size: page_content='invoice.  \nTerms & Conditions' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
# chunk # 225, size: page_content='Globex  Standard Terms and Conditions govern this Statement of Work a nd may be viewed' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
# chunk # 226, size: page_content='at http://www.globex.com/saas/agreements/master.html .  \nSignatures  \n \nGlobex , Inc.' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
# chunk # 227, size: page_content='Consulting services  ACME  \n \n \n  \n \n \nName:    Name:' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
# chunk # 228, size: page_content='Title :  VP consulting services  Title:  Procurement Director  \nDate :   Date:' metadata={'source': './PDFS/sample-statement-of-work.pdf', 'page': 8}
